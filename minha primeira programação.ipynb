# %% [markdown]
# ## aula de programação
#
# - Estou gostando muito de pynthon
#
# - Querendo aprender mais
#
#
# > é muito bom

# %% [markdown]
# ![RobloxScreenShot20230914_104422784.png](attachment:RobloxScreenShot20230914_104422784.png)

# %%
# Com certeza
print ("Jesus vai me ajudar")
# Out:
# Jesus vai me ajudar

# %%
print ("Amém")
# Out:
# Amém

# %%
num = 5

# %%
# adicionando 35
num = num +35

# %%
num = num *20

# %%
num = num +10

# %%
print (num)
# Out:
# 840

# %%
num = 25

# %%
num = num *100

# %%
print(num)
# Out:
# 100
